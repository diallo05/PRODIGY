# %%
import pandas as pd 
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Sélection des variables pertinentes
X = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# Normalisation des données
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# selection des nbres clusters 

centre_inertie = []
for i in range(1, 11):
    kmeans=KMeans(n_clusters=i , init='k-means++', random_state=0)
    kmeans.fit(X_scaled)
    centre_inertie.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), centre_inertie, marker='o', linestyle='--')
plt.title('Méthode Elbow')
plt.xlabel('Nombre de Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans=KMeans(n_clusters=6, init='k-means++', random_state=42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
from mpl_toolkits.mplot3d import Axes3D

# Visualisation 3D des clusters
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Créer un scatter plot pour chaque cluster
for cluster_label in set(clusters):
    ax.scatter(
        X_scaled[clusters == cluster_label, 0],  # Age
        X_scaled[clusters == cluster_label, 1],  # Income
        X_scaled[clusters == cluster_label, 2],  # Spending Score
        label=f'Cluster {cluster_label}',
        s=50
    )

# Ajouter des détails au graphique
ax.set_title('Clusters de Clients (3D)')
ax.set_xlabel('Age (normalisé)')
ax.set_ylabel('Income (normalisé)')
ax.set_zlabel('Spending Score (normalisé)')
plt.legend(title="Clusters", loc="upper left")
plt.show()
